# %%
import pandas as pd

# %%
from google.colab import files
data_to_load = files.upload()

# %%
import io
df = pd.read_csv(io.BytesIO(data_to_load['AgeDB_excel.csv']))
df.head()

# %%
name=[]
age=[]
label=[]
gender=[]

for i in df['Image']:
  x=i.split("_")
  label.append(x[0])
  name.append(x[1])
  age.append(x[2])
  gender.append(x[3])


final_gender=[]
for j in gender:
  y=j.split(".")
  final_gender.append(y[0])

print(final_gender)
# Out:
# ['f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'm
# ...

# %%
import numpy as np

np.reshape(label, (-1,1))

label[15999:16488]
# Out:
# ['9561',
#  '9562',
#  '9563',
#  '9564',
#  '9565',
#  '9566',
#  '9567',
#  '9568',
#  '9569',
#  '956',
#  '9570',
#  '9571',
#  '9572',
#  '9573',
#  '9574',
#  '9575',
#  '9576',
#  '9577',
#  '9578',
#  '9579',
#  '957',
#  '9580',
#  '9581',
#  '9582',
#  '9583',
#  '9584',
#  '9585',
#  '9586',
#  '9587',
#  '9588',
#  '9589',
#  '958',
#  '9590',
#  '9591',
#  '9592',
#  '9593',
#  '9594',
#  '9595',
#  '9596',
#  '9597',
#  '9598',
#  '9599',
#  '959',
#  '95',
#  '9600',
#  '9601',
#  '9602',
#  '9603',
#  '9604',
#  '9605',
#  '9606',
#  '9607',
#  '9608',
#  '9609',
#  '960',
#  '9610',
#  '9611',
#  '9612',
#  '9613',
#  '9614',
#  '9615',
#  '9616',
#  '9617',
#  '9618',
#  '9619',
#  '961',
#  '9620',
#  '9621',
#  '9622',
#  '9623',
#  '9624',
#  '9625',
#  '9626',
#  '9627',
#  '9628',
#  '9629',
#  '962',
#  '9630',
#  '9631',
#  '9632',
#  '9633',
#  '9634',
#  '9635',
#  '9636',
#  '9637',
#  '9638',
#  '9639',
#  '963',
#  '9640',
#  '9641',
#  '9642',
# ...
